# %%
from pathlib import pathlib

import pandas as pd 
import numpy as np 

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", None)
pad.set_option("display.max_colwidth", None)
